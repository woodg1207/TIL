# %% [markdown]
# [toc]

# %% [markdown]
# # 시각화 하기
# 1. 분석에 도움이된다.  이상점 채크가능
# 2. 리포팅에 도움이 된다.

# %%
# %matplotlib inline
import pandas as pd

# %% [markdown]
# ## 1. 선그래프
# 숫자에 대해서만 나오는것

# %%
df = pd.read_csv('./data/broadcast.csv', index_col=0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df.plot() #kind='line'

# %%
df.plot(y='KBS')

# %%
df.plot(y=['KBS','JTBC'])

# %%
df[['KBS','JTBC']].plot()

# %%
df['KBS'].plot()

# %% [markdown]
# ## 2. 막대 그래프
# 카테고리를 비교하기위해서 사용한다.

# %%
df = pd.read_csv('./data/sports.csv', index_col=0)
df
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh')

# %%
df.plot(kind='bar', stacked=True)

# %%
df['Female'].plot(kind='bar')

# %% [markdown]
# ## 3. 파이 그래프
# 비율 표현에 우수

# %%
df = pd.read_csv('./data/broadcast.csv', index_col=0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df.loc[2017]
# Out:
# KBS          26.890
# MBC          12.465
# SBS           8.661
# TV CHOSUN     8.886
# JTBC          9.453
# Channel A     6.056
# MBN           5.215
# Name: 2017, dtype: float64

# %%
df.loc[2017].plot(kind='pie')

# %%
df.plot(kind='pie', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000164B59E6248>,
# ...
#       dtype=object)

# %% [markdown]
# ## 4. 히스토그램
# 항목을 범위로 보는것

# %%
df = pd.read_csv('./data/body.csv', index_col=0)
df
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# ...        ...     ...
# 996      171.8    68.2
# 997      171.5    75.6
# 998      177.9    66.5
# 999      174.4    72.0
# 1000     173.5    77.4
#
# [1000 rows x 2 columns]

# %%
df.plot(kind='hist',y='Height') # 범위는 10개

# %%
df.plot(kind='hist',y='Height',bins=15)

# %% [markdown]
# ## 5. 박스 플롯
# 통계정보를 시각적으로 구현
# 최댓값,
# 최솟값,
# 중간값(50% 지점, q2),
# 75%지점 q3,
# 25%지점 q1,
# 이상점(outliters)

# %%
df = pd.read_csv('data/exam.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
df.plot(kind='box',y='math score')

# %%
df.plot(kind='box',y=['math score', 'reading score', 'writing score'])

# %% [markdown]
# ## 6. 산점도

# %%
df.plot(kind='scatter',x='math score', y='reading score')

# %%
df.plot(kind='scatter',x='math score', y='writing score')

# %%
df.plot(kind='scatter',x='reading score', y='writing score')

# %% [markdown]
# ### 연습문제 :1

# %%
# %matplotlib inline
import pandas as pd
df = pd.read_csv('data/gdp.csv', index_col=0)
df
# Out:
#              Aruba        Angola       Albania       Andorra    Arab World  \
# 2000  1.873453e+09  9.129595e+09  3.480355e+09  1.434430e+09  7.351881e+11
# 2001  1.920112e+09  8.936064e+09  3.922101e+09  1.496913e+09  7.234491e+11
# 2002  1.941341e+09  1.528559e+10  4.348068e+09  1.733117e+09  7.292314e+11
# 2003  2.021229e+09  1.781271e+10  5.611496e+09  2.398646e+09  8.233413e+11
# 2004  2.228492e+09  2.355205e+10  7.184686e+09  2.935659e+09  9.643273e+11
# 2005  2.330726e+09  3.697092e+10  8.052074e+09  3.255789e+09  1.185143e+12
# 2006  2.424581e+09  5.238101e+10  8.896073e+09  3.543257e+09  1.404653e+12
# 2007  2.615084e+09  6.526645e+10  1.067732e+10  4.016972e+09  1.638214e+12
# 2008  2.745251e+09  8.853861e+10  1.288135e+10  4.007353e+09  2.078570e+12
# 2009  2.498883e+09  7.030716e+10  1.204421e+10  3.660531e+09  1.796200e+12
# 2010  2.390503e+09  8.379950e+10  1.192696e+10  3.355695e+09  2.109932e+12
# ...

# %%
df[["Korea_Rep", "United_States", "United_Kingdom", "Germany", "China", "Japan"]].plot()

# %% [markdown]
# ### 연습문제 :2

# %%
df = pd.read_csv('data/silicon_valley_summary.csv')
df
# Out:
#      job_category             race_ethnicity  gender   count  percentage
# 0     All workers                      White    Male  268883   41.257252
# 1     All workers                      White  Female  105560   16.197065
# 2     All workers  Black_or_African American    Male   17508    2.686417
# 3     All workers  Black_or_African American  Female   11479    1.761331
# 4     All workers                      Asian    Male  125347   19.233171
# 5     All workers                      Asian  Female   58049    8.907005
# 6     All workers         Hispanic_or_Latino    Male   32201    4.940903
# 7     All workers         Hispanic_or_Latino  Female   15512    2.380152
# 8     All workers                        All    Male  454813   69.786244
# 9     All workers                        All  Female  196910   30.213756
# 10    All workers                     Totals    Both  651723  100.000000
# 11     Executives                      White    Male    7282   58.678485
# ...

# %%
df.loc[(df['race_ethnicity']!='All')&(df['job_category']=='Managers')&(df['gender']=='Male')].plot(kind='bar',x='race_ethnicity',y='count')

# %%
###정답
df = pd.read_csv('data/silicon_valley_summary.csv')
boolean_male = df['gender']=='Male'
boolean_manager = df['job_category'] == 'Managers'
boolean_not_all = df['race_ethnicity'] != 'All'

df[boolean_male & boolean_manager & boolean_not_all].plot(kind='bar', x='race_ethnicity',  y='count')

# %%
df = pd.read_csv('data/silicon_valley_details.csv')
df
# Out:
#       company  year                race gender          job_category  count
# 0     23andMe  2016  Hispanic_or_Latino   male            Executives      0
# 1     23andMe  2016  Hispanic_or_Latino   male              Managers      1
# 2     23andMe  2016  Hispanic_or_Latino   male         Professionals      7
# 3     23andMe  2016  Hispanic_or_Latino   male           Technicians      0
# 4     23andMe  2016  Hispanic_or_Latino   male         Sales workers      0
# ...       ...   ...                 ...    ...                   ...    ...
# 4435  Sanmina  2016      Overall_totals    NaN  laborers and helpers      4
# 4436  Sanmina  2016      Overall_totals    NaN       Service workers     57
# 4437  Sanmina  2016      Overall_totals    NaN                Totals   5205
# 4438  Sanmina  2016      Overall_totals    NaN       Previous_totals   5615
# 4439  Sanmina  2016      Overall_totals    NaN              Managers    591
#
# [4440 rows x 6 columns]

# %%
df = pd.read_csv('data/silicon_valley_details.csv')
df.set_index('job_category',inplace=True)
df.loc[('Totals')&(df['race']=='Overall_totals')&(df['company']=='Adobe')&(df['count']!=0)].plot(kind='pie',y='count')
df
# Out:
#                       company  year                race gender  count
# job_category
# Executives            23andMe  2016  Hispanic_or_Latino   male      0
# Managers              23andMe  2016  Hispanic_or_Latino   male      1
# Professionals         23andMe  2016  Hispanic_or_Latino   male      7
# Technicians           23andMe  2016  Hispanic_or_Latino   male      0
# Sales workers         23andMe  2016  Hispanic_or_Latino   male      0
# ...                       ...   ...                 ...    ...    ...
# laborers and helpers  Sanmina  2016      Overall_totals    NaN      4
# Service workers       Sanmina  2016      Overall_totals    NaN     57
# Totals                Sanmina  2016      Overall_totals    NaN   5205
# Previous_totals       Sanmina  2016      Overall_totals    NaN   5615
# Managers              Sanmina  2016      Overall_totals    NaN    591
#
# [4440 rows x 5 columns]

# %%
boolean_adobe = df['company'] == 'Adobe'
boolean_all_races = df['race'] == 'Overall_totals'
boolean_count = df['count'] != 0
boolean_job_category = (df['job_category'] != 'Totals') & (df['job_category'] != 'Previous_totals')

df_adobe = df[boolean_adobe & boolean_all_races & boolean_count & boolean_job_category]
df_adobe.set_index('job_category', inplace=True)
df_adobe.plot(kind='pie', y= 'count')

# %% [markdown]
# ### 연습문제 :4

# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv('data/starbucks_drinks.csv')
df.plot(kind='box',y='Calories')

# %% [markdown]
# ### 연습문제 : 5

# %%
df = pd.read_csv('data/world_indexes.csv')
df
# Out:
#                            Id  Human Development Index HDI-2014  \
# 0                      Norway                          0.943877
# 1                   Australia                          0.934958
# 2                 Switzerland                          0.929613
# 3                     Denmark                          0.923328
# 4                 Netherlands                          0.921794
# ..                        ...                               ...
# 183                   Burundi                          0.399928
# 184                      Chad                          0.391906
# 185                   Eritrea                          0.390899
# 186  Central African Republic                          0.350131
# 187                     Niger                          0.348254
#
#      Gini coefficient 2005-2013  \
# 0                         26.83
# 1                         34.01
# 2                         32.35
# 3                         26.88
# ...

# %%
df.plot()
